# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/greekLyrics_ansi.csv', delimiter=';', encoding='iso8859_7')
print(df.info())

print("All genres:", df['genre'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 862 entries, 0 to 861
# Data columns (total 4 columns):
# genre     862 non-null object
# title     862 non-null object
# artist    862 non-null object
# lyrics    861 non-null object
# dtypes: object(4)
# memory usage: 27.1+ KB
# None
# All genres: ['Τσιφτετέλι' 'Παραδοσιακό Πόντου' 'Ρεμπέτικο' 'Έντεχνο' 'Αφήγηση'
#  'Μπαλάντα' 'Νησιώτικο' 'Λαικό' 'RAP' 'Ποπ' 'Παραδοσιακό Θράκης' 'Τάνγκο'
#  'Λάτιν' 'Παραδοσιακό' 'Παραδοσιακό Πελοποννήσου' 'Κλασική'
#  'Παραδοσιακό Κύπρου' 'Παραδοσιακό Μακεδονίας' 'Παραδοσιακό Ηπείρου'
#  'Ελληνικό Ποπ' 'Αμελοποίητο' 'Pop' 'Foxtrot' 'Hip Hop' 'R&B' 'Reggae'
#  'Swing' 'Βαλς' 'Tango' 'Λαικό Μπαλάντα' 'Παραδοσιακό Κρήτης'
#  'Ελληνική μπαλάντα' 'Ύμνος' 'Ελληνικό λαικό' 'Παραδοσιακό Χίου'
#  'Ελληνικό Ροκ' 'Ελληνικό Ραπ' 'Ραπ' 'Bossa Νova' 'Ελληνικό χιπ χοπ'
#  'Δημοτικό' 'Παραδοσιακό Κυκλάδες' 'Παραδοσιακό Μικράς Ασίας' 'Ποντιακό'
#  'Τζαζ' 'Παιδικό' 'Απαγγελία' 'Ξένο Παραδοσιακό' 'Παραδοσιακό Θεσσαλίας'
#  'Ταραντέλα' 'Ελληνικό RAP' 'Παραδοσιακό Αρμενίας' 'Beguine'
#  "Rock 'n' roll" 'Καντάδα' 'Εκκλησιαστικό' 'Τσάρλεστον' 'Twist'
#  'Παραδοσιακό Σμύρνης' 'Παραδοσιακό Ρωσίας' 'Λυρικό' 'Παραδοσιακό Ικαρίας'
#  'Μαντινάδα' 'ροκ-ποπ' 'Ροκ' 'Παραδοσιακό Κάσου' 'Βυζαντινό'
#  'Παραδοσιακό Ανδαλουσίας' 'Παραδοσιακό Ανατολής' 'Disco'
#  'Παραδοσιακό Καλύμνου' 'Παραδοσιακό Τουρκίας' 'Παραδοσιακό Γαλλίας']

# %%
print(df.groupby(['genre']).count().to_string())
# Out:
#                           title  artist  lyrics
# genre
# Beguine                       9       9       9
# Bossa Νova                   10      10      10
# Disco                         1       1       1
# Foxtrot                      10      10      10
# Hip Hop                      25      25      25
# Pop                          24      24      24
# R&B                           7       7       7
# RAP                          25      25      25
# Reggae                       25      25      25
# Rock 'n' roll                 5       5       5
# Swing                        14      14      14
# Tango                        25      25      25
# Twist                         2       2       2
# Έντεχνο                      25      25      25
# Ύμνος                        11      11      11
# Αμελοποίητο                  25      25      25
# Απαγγελία                    14      14      14
# Αφήγηση                      22      22      22
# Βαλς                         25      25      25
# Βυζαντινό                     1       1       1
# Δημοτικό                     25      25      25
# Εκκλησιαστικό                 1       1       1
# Ελληνική μπαλάντα            25      25      25
# Ελληνικό RAP                  3       3       3
# Ελληνικό Ποπ                 24      24      24
# Ελληνικό Ραπ                 25      25      24
# Ελληνικό Ροκ                 25      25      25
# Ελληνικό λαικό               25      25      25
# Ελληνικό χιπ χοπ             14      14      14
# Καντάδα                       6       6       6
# Κλασική                       1       1       1
# Λάτιν                        24      24      24
# Λαικό                        24      24      24
# Λαικό Μπαλάντα               16      16      16
# Λυρικό                        1       1       1
# Μαντινάδα                     1       1       1
# Μπαλάντα                     25      25      25
# Νησιώτικο                    21      21      21
# Ξένο Παραδοσιακό              4       4       4
# Παιδικό                      12      12      12
# Παραδοσιακό                  25      25      25
# Παραδοσιακό Ανατολής          1       1       1
# Παραδοσιακό Ανδαλουσίας       1       1       1
# Παραδοσιακό Αρμενίας          7       7       7
# Παραδοσιακό Γαλλίας           1       1       1
# Παραδοσιακό Ηπείρου           8       8       8
# Παραδοσιακό Θεσσαλίας         2       2       2
# Παραδοσιακό Θράκης            6       6       6
# Παραδοσιακό Ικαρίας           1       1       1
# Παραδοσιακό Κάσου             1       1       1
# Παραδοσιακό Καλύμνου          1       1       1
# Παραδοσιακό Κρήτης           25      25      25
# Παραδοσιακό Κυκλάδες          8       8       8
# Παραδοσιακό Κύπρου           14      14      14
# Παραδοσιακό Μακεδονίας        8       8       8
# Παραδοσιακό Μικράς Ασίας     25      25      25
# Παραδοσιακό Πελοποννήσου      8       8       8
# Παραδοσιακό Πόντου            9       9       9
# Παραδοσιακό Ρωσίας            1       1       1
# Παραδοσιακό Σμύρνης           3       3       3
# Παραδοσιακό Τουρκίας          1       1       1
# Παραδοσιακό Χίου              4       4       4
# Ποντιακό                      5       5       5
# Ποπ                          25      25      25
# Ραπ                           3       3       3
# Ρεμπέτικο                    24      24      24
# Ροκ                           3       3       3
# Τάνγκο                       25      25      25
# Ταραντέλα                     2       2       2
# Τζαζ                          4       4       4
# Τσάρλεστον                    1       1       1
# Τσιφτετέλι                    2       2       2
# ροκ-ποπ                       1       1       1

# %%
booleanDF = (df.groupby(['genre']).count()>10)

# %%
genreToRemove = booleanDF[booleanDF['title'] == False]

# %%
genreToRemove = genreToRemove.reset_index()

# %%
genreToRemove
# Out:
#                        genre  title  artist  lyrics
# 0                    Beguine  False   False   False
# 1                 Bossa Νova  False   False   False
# 2                      Disco  False   False   False
# 3                    Foxtrot  False   False   False
# 4                        R&B  False   False   False
# 5              Rock 'n' roll  False   False   False
# 6                      Twist  False   False   False
# 7                  Βυζαντινό  False   False   False
# 8              Εκκλησιαστικό  False   False   False
# 9               Ελληνικό RAP  False   False   False
# 10                   Καντάδα  False   False   False
# 11                   Κλασική  False   False   False
# 12                    Λυρικό  False   False   False
# 13                 Μαντινάδα  False   False   False
# 14          Ξένο Παραδοσιακό  False   False   False
# 15      Παραδοσιακό Ανατολής  False   False   False
# 16   Παραδοσιακό Ανδαλουσίας  False   False   False
# 17      Παραδοσιακό Αρμενίας  False   False   False
# 18       Παραδοσιακό Γαλλίας  False   False   False
# 19       Παραδοσιακό Ηπείρου  False   False   False
# 20     Παραδοσιακό Θεσσαλίας  False   False   False
# 21        Παραδοσιακό Θράκης  False   False   False
# 22       Παραδοσιακό Ικαρίας  False   False   False
# 23         Παραδοσιακό Κάσου  False   False   False
# 24      Παραδοσιακό Καλύμνου  False   False   False
# 25      Παραδοσιακό Κυκλάδες  False   False   False
# 26    Παραδοσιακό Μακεδονίας  False   False   False
# 27  Παραδοσιακό Πελοποννήσου  False   False   False
# 28        Παραδοσιακό Πόντου  False   False   False
# 29        Παραδοσιακό Ρωσίας  False   False   False
# 30       Παραδοσιακό Σμύρνης  False   False   False
# 31      Παραδοσιακό Τουρκίας  False   False   False
# 32          Παραδοσιακό Χίου  False   False   False
# 33                  Ποντιακό  False   False   False
# 34                       Ραπ  False   False   False
# 35                       Ροκ  False   False   False
# 36                 Ταραντέλα  False   False   False
# 37                      Τζαζ  False   False   False
# 38                Τσάρλεστον  False   False   False
# 39                Τσιφτετέλι  False   False   False
# 40                   ροκ-ποπ  False   False   False

# %%
for index, row in genreToRemove.iterrows():
    print(row['genre'])
    delete_row = df[df['genre'] == row['genre']].index
    df.drop(delete_row, inplace=True)
# Out:
# Beguine
# Bossa Νova
# Disco
# Foxtrot
# R&B
# Rock 'n' roll
# Twist
# Βυζαντινό
# Εκκλησιαστικό
# Ελληνικό RAP
# Καντάδα
# Κλασική
# Λυρικό
# Μαντινάδα
# Ξένο Παραδοσιακό
# Παραδοσιακό Ανατολής
# Παραδοσιακό Ανδαλουσίας
# Παραδοσιακό Αρμενίας
# Παραδοσιακό Γαλλίας
# Παραδοσιακό Ηπείρου
# Παραδοσιακό Θεσσαλίας
# Παραδοσιακό Θράκης
# Παραδοσιακό Ικαρίας
# Παραδοσιακό Κάσου
# Παραδοσιακό Καλύμνου
# Παραδοσιακό Κυκλάδες
# Παραδοσιακό Μακεδονίας
# Παραδοσιακό Πελοποννήσου
# Παραδοσιακό Πόντου
# Παραδοσιακό Ρωσίας
# Παραδοσιακό Σμύρνης
# Παραδοσιακό Τουρκίας
# Παραδοσιακό Χίου
# Ποντιακό
# Ραπ
# Ροκ
# Ταραντέλα
# Τζαζ
# Τσάρλεστον
# Τσιφτετέλι
# ροκ-ποπ

# %%
df.to_csv('output.csv')

# %%
df['genre'].unique()
# Out:
# array(['Ρεμπέτικο', 'Έντεχνο', 'Αφήγηση', 'Μπαλάντα', 'Νησιώτικο',
#        'Λαικό', 'rap', 'Ποπ', 'Τάνγκο', 'Λάτιν', 'Παραδοσιακό',
#        'Παραδοσιακό Κύπρου', 'Ελληνικό Ποπ', 'Αμελοποίητο', 'Pop',
#        'Reggae', 'Swing', 'Βαλς', 'Tango', 'Λαικό Μπαλάντα',
#        'Παραδοσιακό Κρήτης', 'Ελληνική μπαλάντα', 'Ύμνος',
#        'Ελληνικό λαικό', 'Ελληνικό Ροκ', 'Δημοτικό',
#        'Παραδοσιακό Μικράς Ασίας', 'Παιδικό', 'Απαγγελία'], dtype=object)

# %%
rapList = ["RAP","Hip Hop","Ελληνικό Ραπ","Ελληνικό χιπ χοπ"]
pop_rockList = ["Ποπ", "Pop", "Ελληνικό Ροκ", "Ελληνικό Ποπ"]
for index, row in df.iterrows():
    if(row['genre'] in rapList):
        row['genre'] = "rap"
    elif(row['genre'] in pop_rockList):
        row['genre'] = "pop-rock"

# %%
df['genre'].value_counts()
# Out:
# pop-rock                    98
# rap                         89
# Έντεχνο                     25
# Μπαλάντα                    25
# Βαλς                        25
# Παραδοσιακό Κρήτης          25
# Παραδοσιακό Μικράς Ασίας    25
# Reggae                      25
# Tango                       25
# Τάνγκο                      25
# Ελληνικό λαικό              25
# Ελληνική μπαλάντα           25
# Παραδοσιακό                 25
# Δημοτικό                    25
# Αμελοποίητο                 25
# Λάτιν                       24
# Λαικό                       24
# Ρεμπέτικο                   24
# Αφήγηση                     22
# Νησιώτικο                   21
# Λαικό Μπαλάντα              16
# Παραδοσιακό Κύπρου          14
# Swing                       14
# Απαγγελία                   14
# Παιδικό                     12
# Ύμνος                       11
# Name: genre, dtype: int64
